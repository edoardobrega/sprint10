# %% [markdown]
# lista 50 peliculas mas recaudadoras españa

# %%
import requests
import csv

movie_links = [
    "https://www.omdbapi.com/?t=Avatar&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Spanish%20Affairs&apikey=d2ebbf03",  # 8 APELLIDOS VASCOS
    "https://www.omdbapi.com/?t=Avatar%20The%20Way%20of%20Water&apikey=d2ebbf03",  # Avatar: El Sentido del Agua
    "https://www.omdbapi.com/?t=Inside%20Out%202&apikey=d2ebbf03",  # Inside Out 2
    "https://www.omdbapi.com/?t=Titanic&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=The%20Impossible&apikey=d2ebbf03",  # Lo Imposible
    "https://www.omdbapi.com/?t=The%20Lion%20King&apikey=d2ebbf03",  # El Rey Leon
    "https://www.omdbapi.com/?t=Spanish%20Affairs%20Catalonia&apikey=d2ebbf03",  # Ocho Apellidos Catalanes
    "https://www.omdbapi.com/?t=The%20Lord%20of%20the%20Rings%3A%20The%20Return%20of%20the%20King&apikey=d2ebbf03",  # El Señor de los Anillos: El Retorno del Rey
    "https://www.omdbapi.com/?t=Barbie&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Star%20Wars%3A%20The%20Force%20Awakens&apikey=d2ebbf03",  # Star Wars: El Despertar de la Fuerza
    "https://www.omdbapi.com/?t=The%20Lord%20of%20the%20Rings%3A%20The%20Fellowship%20of%20the%20Ring&apikey=d2ebbf03",  # El Señor de los Anillos: La Comunidad del Anillo
    "https://www.omdbapi.com/?t=Joker&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=The%20Lord%20of%20the%20Rings%3A%20The%20Two%20Towers&apikey=d2ebbf03",  # El Señor de los Anillos: Las Dos Torres
    "https://www.omdbapi.com/?t=Avengers%3A%20Endgame&apikey=d2ebbf03",  # Vengadores: Endgame
    "https://www.omdbapi.com/?t=Spider-Man%3A%20No%20Way%20Home&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Harry%20Potter%20and%20the%20Philosopher%27s%20Stone&apikey=d2ebbf03",  # Harry Potter y la Piedra Filosofal
    "https://www.omdbapi.com/?t=Pirates%20of%20the%20Caribbean%3A%20Dead%20Man%27s%20Chest&apikey=d2ebbf03",  # Piratas del Caribe: El Cofre del Hombre Muerto
    "https://www.omdbapi.com/?t=Shrek%202&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Bohemian%20Rhapsody&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=The%20Super%20Mario%20Bros.%20Movie&apikey=d2ebbf03",  # Super Mario Bros. La película
    "https://www.omdbapi.com/?t=The%20Others&apikey=d2ebbf03",  # Los Otros
    "https://www.omdbapi.com/?t=The%20Da%20Vinci%20Code&apikey=d2ebbf03",  # Codigo Da Vinci
    "https://www.omdbapi.com/?t=The%20Sixth%20Sense&apikey=d2ebbf03",  # El Sexto Sentido
    "https://www.omdbapi.com/?t=A%20Monster%20Calls&apikey=d2ebbf03",  # Un Monstruo Viene A Verme
    "https://www.omdbapi.com/?t=Aladdin&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=The%20Orphanage&apikey=d2ebbf03",  # El Orfanato
    "https://www.omdbapi.com/?t=Toy%20Story%203&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Up&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Star%20Wars%3A%20The%20Phantom%20Menace&apikey=d2ebbf03",  # Star Wars Episodio 1: La amenaza fantasma
    "https://www.omdbapi.com/?t=Jurassic%20World%3A%20Fallen%20Kingdom&apikey=d2ebbf03",  # Jurassic World: El Reino Caído
    "https://www.omdbapi.com/?t=Minions&apikey=d2ebbf03",  # Los Minions
    "https://www.omdbapi.com/?t=Deadpool%20and%20Wolverine&apikey=d2ebbf03",  # Deadpool y Lobezno
    "https://www.omdbapi.com/?t=Harry%20Potter%20and%20the%20Chamber%20of%20Secrets&apikey=d2ebbf03",  # Harry Potter y la Cámara Secreta
    "https://www.omdbapi.com/?t=Finding%20Nemo&apikey=d2ebbf03",  # Buscando a Nemo
    "https://www.omdbapi.com/?t=Mortadelo%20and%20Filemon%20The%20Big%20Adventure&apikey=d2ebbf03",  # Mortadelo y Filemón, La
    "https://www.omdbapi.com/?t=The%20Hobbit%3A%20An%20Unexpected%20Journey&apikey=d2ebbf03",  # El Hobbit: Un Viaje Inesperado
    "https://www.omdbapi.com/?t=Pirates%20of%20the%20Caribbean%3A%20At%20World%27s%20End&apikey=d2ebbf03",  # Piratas del Caribe: En el Fin del Mundo
    "https://www.omdbapi.com/?t=Spider-Man%202024&apikey=d2ebbf03",  # Spider-Man (2024)
    "https://www.omdbapi.com/?t=Alice%20in%20Wonderland&apikey=d2ebbf03",  # Alicia en el Pais de las Maravillas
    "https://www.omdbapi.com/?t=Spider-Man%202002&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=The%20Twilight%20Saga%3A%20Breaking%20Dawn%20Part%202&apikey=d2ebbf03",  # Saga Crepúsculo. Amanecer – Parte II
    "https://www.omdbapi.com/?t=Shrek%20the%20Third&apikey=d2ebbf03",  # Shrek Tercero
    "https://www.omdbapi.com/?t=Pirates%20of%20the%20Caribbean%3A%20The%20Curse%20of%20the%20Black%20Pearl&apikey=d2ebbf03",  # Piratas del Caribe: La Maldición de la Perla Negra
    "https://www.omdbapi.com/?t=Torrente%202%3A%20Mission%20in%20Marbella&apikey=d2ebbf03",  # Torrente 2: Misión en Marbella
    "https://www.omdbapi.com/?t=Toy%20Story%204&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Beauty%20and%20the%20Beast&apikey=d2ebbf03",  # La Bella y la Bestia
    "https://www.omdbapi.com/?t=Jurassic%20World&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Inside%20Out&apikey=d2ebbf03",
    "https://www.omdbapi.com/?t=Ice%20Age%3A%20Dawn%20of%20the%20Dinosaurs&apikey=d2ebbf03"  # Ice Age 3: El Origen de los Dinosaurios
]


movie_data_list = []

for link in movie_links:
    response = requests.get(link)
    if response.status_code == 200:
        movie_data = response.json()
        
        if movie_data.get("Response") == "True":
            movie_data_list.append({
                'Title': movie_data.get('Title'),
                'Year': movie_data.get('Year'),
                'Rated': movie_data.get('Rated'),
                'Released': movie_data.get('Released'),
                'Runtime': movie_data.get('Runtime'),
                'Genre': movie_data.get('Genre'),
                'Director': movie_data.get('Director'),
                'Writer': movie_data.get('Writer'),
                'Actors': movie_data.get('Actors'),
                'Plot': movie_data.get('Plot'),
                'Language': movie_data.get('Language'),
                'Country': movie_data.get('Country'),
                'Awards': movie_data.get('Awards'),
                'Poster': movie_data.get('Poster'),
                'imdbRating': movie_data.get('imdbRating'),
                'imdbVotes': movie_data.get('imdbVotes'),
                'BoxOffice': movie_data.get('BoxOffice')
            })

file_path = r'C:\Users\Usuario\Downloads\proyecto\movies_data_esp.csv'

keys = movie_data_list[0].keys() if movie_data_list else []
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=keys)
    writer.writeheader()
    writer.writerows(movie_data_list)

print(f"File CSV creato con successo in: {file_path}")

# %% [markdown]
# lista 50 peliculas mas recaudadoras mundo

# %%
import requests
import csv

movie_titles = [
    "Aladdin", "Aquaman", "Avatar", "Avatar: The Way of Water", "Avengers: Age of Ultron", 
    "Avengers: Endgame", "Avengers: Infinity War", "Barbie", "Beauty and the Beast", "Black Panther",
    "Captain America: Civil War", "Captain Marvel", "Deadpool & Wolverine", "Despicable Me 3", 
    "Frozen", "Frozen II", "Furious 7", "Harry Potter and the Deathly Hallows: Part 2", 
    "Incredibles 2", "Inside Out 2", "Iron Man 3", "Joker", "Jurassic Park", "Jurassic World", 
    "Jurassic World: Fallen Kingdom", "Minions", "Moana 2", "Ne Zha 2", "Pirates of the Caribbean: Dead Man's Chest", 
    "Pirates of the Caribbean: On Stranger Tides", "Rogue One: A Star Wars Story", "Skyfall", 
    "Spider-Man: Far from Home", "Spider-Man: No Way Home", "Star Wars: Episode I - The Phantom Menace", 
    "Star Wars: The Force Awakens", "Star Wars: The Last Jedi", "Star Wars: The Rise of Skywalker", 
    "The Avengers", "The Dark Knight Rises", "The Fate of the Furious", "The Lion King", 
    "The Lord of the Rings: The Return of the King", "The Super Mario Bros. Movie", "Titanic", 
    "Top Gun: Maverick", "Toy Story 3", "Toy Story 4", "Transformers: Age of Extinction", "Transformers: Dark of the Moon"
]

movie_links = [
    f"https://www.omdbapi.com/?t={title.replace(' ', '%20')}&apikey=d2ebbf03" 
    for title in movie_titles
]

movie_links_with_comments = [
    f'"{link}",  # {title}' for link, title in zip(movie_links, movie_titles)
]

for link in movie_links_with_comments:
    print(link)

file_path = r'C:\Users\Usuario\Downloads\progetto\movie_links_1.txt'
with open(file_path, 'w', encoding='utf-8') as file:
    file.write("\n".join(movie_links_with_comments))

print(f"File con i link generato con successo in: {file_path}")

# %% [markdown]
# lista albo de oro mejor pelicula oscar

# %%
import requests
import csv

movie_titles = [
    "12 Years a Slave", "A Beautiful Mind", "A Man for All Seasons", "All Quiet on the Western Front", 
    "All the King's Men", "Amadeus", "American Beauty", "An American in Paris", "Annie Hall", "Argo", 
    "Around the World in 80 Days", "Ben-Hur", "Birdman or (The Unexpected Virtue of Ignorance)", "Braveheart", 
    "Cavalcade", "Chariots of Fire", "Chicago", "Cimarron", "CODA", "Crash", "Dances with Wolves", 
    "Driving Miss Daisy", "Everything Everywhere All at Once", "Forrest Gump", "From Here to Eternity", 
    "Gandhi", "Gentleman's Agreement", "Gigi", "Gladiator", "Going My Way", "Gone with the Wind", "Grand Hotel", 
    "Green Book", "Hamlet", "How Green Was My Valley", "In the Heat of the Night", "It Happened One Night", 
    "Kramer vs. Kramer", "Lawrence of Arabia", "Marty", "Midnight Cowboy", "Million Dollar Baby", "Moonlight", 
    "Mrs. Miniver", "Mutiny on the Bounty", "My Fair Lady", "No Country for Old Men", "Nomadland", "Oliver!", 
    "On the Waterfront", "One Flew Over the Cuckoo's Nest", "Ordinary People", "Out of Africa", "Parasite", 
    "Patton", "Platoon", "Rain Man", "Rebecca", "Rocky", "Schindler's List", "Shakespeare in Love", 
    "Slumdog Millionaire", "Spotlight", "Sunrise: A Song of Two Humans", "Terms of Endearment", "The Apartment", 
    "The Artist", "The Best Years of Our Lives", "The Bridge on the River Kwai", "The Broadway Melody", 
    "The Deer Hunter", "The Departed", "The English Patient", "The French Connection", "The Godfather", 
    "The Godfather Part II", "The Great Ziegfeld", "The Greatest Show on Earth", "The Hurt Locker", 
    "The King's Speech", "The Last Emperor", "The Life of Emile Zola", "The Lord of the Rings: The Return of the King", 
    "The Lost Weekend", "The Shape of Water", "The Silence of the Lambs", "The Sound of Music", "The Sting", 
    "The Whale", "Titanic", "Tom Jones", "Unforgiven", "West Side Story", "Wings", "You Can't Take It With You"
]

movie_links = [
    f"https://www.omdbapi.com/?t={title.replace(' ', '%20')}&apikey=d2ebbf03" 
    for title in movie_titles
]

movie_links_with_comments = [
    f'"{link}",  # {title}' for link, title in zip(movie_links, movie_titles)
]

for link in movie_links_with_comments:
    print(link)

file_path = r'C:\Users\Usuario\Downloads\progetto\movie_links_2.txt'
with open(file_path, 'w', encoding='utf-8') as file:
    file.write("\n".join(movie_links_with_comments))

print(f"File con i link generato con successo in: {file_path}")

# %% [markdown]
# lista albo de oro concha de oro

# %%
import requests
import csv

movie_titles = [
    "Badlands", "A Thousand Years of Good Prayers", "Alambrista", "Alas de mariposa", 
    "America America", "Bwana", "C'est quoi la vie?", "City of Life and Death", 
    "Coup de Foudre", "Crai nou", "Dans la maison", "Dasatskisi", "Demonios en el jardín", 
    "Días contados", "Dyrygent", "El espíritu de la colmena", "El viento se llevó lo que", 
    "Entre dos aguas", "Ewa shce spac", "Furtivos", "Giorni d'amore", "Homer and Eddie", 
    "I Was Happy Here", "Il ferroviere", "La guerra de Dios", "La mitad del cielo", 
    "La nonna Sabella", "La perdición de los hombres", "Las cartas de Alou", "Le genou de Claire", 
    "L'isola di Arturo", "Los lunes al sol", "Los pasos dobles", "Los reyes del mundo", 
    "Mafioso", "Magical Girl", "Margaret's Museum", "Mekhanicheskogo pianino", "Mirage", 
    "Mon fils à moi", "NEDS", "Niwemang", "Noce en Galilée", "Notre Mariage", "O corno", 
    "On the Black Hill", "Ondata di calore", "One-Eyed Jacks", "Ossenij Marafon", "Pacificado", 
    "Pandoranin kutusu", "Pelo Malo", "Principio y fin", "Rien ne va plus", "Romeo Juliet a tma", 
    "Rumble Fish", "Schussangst", "Sierra Maldita", "Sparrows", "Stesti", "Storie di ordinaria follia", 
    "Tabor uhodit v cielo", "Tardes de soledad", "Taxi para tres", "The Disaster Artist", "The Glass House", 
    "The Long Day's Dying", "The Nun's Story", "The Rain People", "Todos somos necesarios", "Turtles Can Fly", 
    "Two for the Road", "Un lugar en el mundo", "Wo bu shi pan jin lian", "Yesterday"
]

movie_links = [
    f"https://www.omdbapi.com/?t={title.replace(' ', '%20')}&apikey=d2ebbf03" 
    for title in movie_titles
]

movie_links_with_comments = [
    f'"{link}",  # {title}' for link, title in zip(movie_links, movie_titles)
]

for link in movie_links_with_comments:
    print(link)

file_path = r'C:\Users\Usuario\Downloads\progetto\movie_links_3.txt'
with open(file_path, 'w', encoding='utf-8') as file:
    file.write("\n".join(movie_links_with_comments))

print(f"File con i link generato con successo in: {file_path}")

# %% [markdown]
# lista albo de oro mejor pelicula sitges

# %%
import requests
import csv

movie_titles = [
    "71 Fragmente einer Chronologie des Zufalls", "Blue Velvet", "Borgman", "C’est arrivé près de chez vous", 
    "Citizen X", "Climax", "Cuando acecha la maldad", "Cube", "Des Teufels Bad", "Dracula: Pages From a Virgin's Diary", 
    "Ed Gein", "El hoyo", "Europa", "Gattaca", "Hard Candy", "Heart of Midnight", "Henry: Portrait of a Serial Killer", 
    "Hol Volt, Hol Nem Volt", "Holy Motors", "I origins", "Jupiter holdja", "Lamb", "Le Dernier Combat", "Long Weekend", 
    "Moon", "Oldboy", "Orlando", "Possessor Uncut", "Rare Exports: A Christmas Tale", "Re-Animator", "Red State", 
    "Réquiem", "Ringu", "Sisu", "Spalovač mrtvol", "Surveillance", "Swiss Army Man", "The Company of Wolves", 
    "The Fall", "The Invitation", "The Navigator: a Medieval Odyssey", "The Pillow Book", "Vidocq", "Zatōichi"
]

movie_links = [
    f"https://www.omdbapi.com/?t={title.replace(' ', '%20').replace(':', '%3A').replace('é', '%E9').replace("'", '%27')}&apikey=d2ebbf03" 
    for title in movie_titles
]

movie_links_with_comments = [
    f'"{link}",  # {title}' for link, title in zip(movie_links, movie_titles)
]

for link in movie_links_with_comments:
    print(link)

file_path = r'C:\Users\Usuario\Downloads\progetto\movie_links_4.txt'
with open(file_path, 'w', encoding='utf-8') as file:
    file.write("\n".join(movie_links_with_comments))

print(f"File con i link generato con successo in: {file_path}")
